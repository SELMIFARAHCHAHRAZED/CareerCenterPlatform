# %% [markdown]
# # Matching using Cosine similariy algorithm

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load the datasets of end-of-study internships (PFE) and resumes for students
internships_offers = pd.read_excel('pfe_dataset.xlsx')
cvs = pd.read_csv('cv_dataset.csv')

# Remove whitespace and split skills column in both DataFrames
internships_offers["Skills"] = internships_offers["Skills"].apply(lambda x: x.split(",") if isinstance(x, str) else [])
cvs["skills"] = cvs["skills"].apply(lambda x: x.split(",") if isinstance(x, str) else [])

# Combine skills into a single string for each offer and resume
internships_offers["Skills_str"] = internships_offers["Skills"].apply(lambda x: " ".join(x))
cvs["skills_str"] = cvs["skills"].apply(lambda x: " ".join(x))

# Use CountVectorizer to create a matrix of skill frequencies for each offer and resume
count_vect = CountVectorizer()
offer_skill_matrix = count_vect.fit_transform(internships_offers["Skills_str"])
cv_skill_matrix = count_vect.transform(cvs["skills_str"])

# Calculate the cosine similarity matrix
cosine_similarity_matrix = cosine_similarity(offer_skill_matrix, cv_skill_matrix)

# Sort the similarity matrix by similarity score
sorted_cosine_similarity_matrix = cosine_similarity_matrix.argsort(axis=1)[:, ::-1]

# Print the top 5 matches for each internship offer
for i, row in enumerate(sorted_cosine_similarity_matrix):
    print("The top 5 matches for internship offer {} are:".format(internships_offers.iloc[i]["Title"]))
    for j in range(5):
        similarity_score = cosine_similarity_matrix[i, row[j]]
        print("  - CV {} with similarity score {}".format(row[j], similarity_score))
# Out:
# The top 5 matches for internship offer DÉVELOPPEMENT D’UN SYSTÈME D'INFO DIVERTISSEMENT SUR UNE IMAGE AGL (AUTOMOTIVE GRADE LINUX) are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer DÉVELOPPEMENT D’UN OUTIL DE DIAGNOSTIC AVEC INTERFACE GRAPHIQUE PERMETTANT DE COMMUNIQUER AVEC UN CALCULATEUR AUTOMOBILE EMBARQUÉ DE TÉLÉMATIQUE (TCU) are:
#   - CV 3993 with similarity score 0.14433756729740646
#   - CV 1758 with similarity score 0.13608276348795437
#   - CV 4067 with similarity score 0.13608276348795437
#   - CV 4154 with similarity score 0.13245323570650439
#   - CV 4083 with similarity score 0.13245323570650439
# The top 5 matches for internship offer DÉVELOPPEMENT D’UNE SOLUTION DE DÉBOGAGE OTA are:
#   - CV 5176 with similarity score 0.5773502691896258
#   - CV 4931 with similarity score 0.5773502691896258
#   - CV 3954 with similarity score 0.5163977794943223
#   - CV 5052 with similarity score 0.5163977794943223
#   - CV 5022 with similarity score 0.5163977794943223
# The top 5 matches for internship offer GPS NMEA GENERATOR FOR TRACKING SYSTEM VIRTUALIZATION AND TESTING are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer CONCEPTION ET DÉVELOPPEMENT D'UN SYSTÈME D'ÉLECTRONIQUE EMBARQUÉ D'AIDE AU STATIONNEMENT are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer ARCHITECTURE MODULAIRE DE FUSION ET PERCEPTION POUR UNE AUTONOMIE DE CONDUITE PLUS SURE are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer CONCEPTION ET IMPLÉMENTATION D’UN SYSTÈME DE GESTION DE BATTERIES LITHIUM-ION POUR VÉLO ÉLECTRIQUE are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer CONCEPTION ET IMPLÉMENTATION D’UNE PASSERELLE RTOS/LINUX SOUS IMX6 are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer OPTIMISATION DU BANC DE QUALIFICATION E-BIKE ET PROGRAMMATION DES PROFILS are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer BUILD MINIMAL RTOS FOR ARM BASED MICROCONTROLLER are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer ETUDE DE FAISABILITÉ DE MIGRATION D'UN BASIC SOFTWARE (BSP) VERS LE STANDARD AUTOMOTIVE AUTOSAR are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer IMPLÉMENTATION D’UN PROTOCOLE DE COMMUNICATION ENTRE DEUX CALCULATEURS AUTOMOBILES (MASTER-SLAVE) are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer IMPLÉMENTATION D’UN DRIVER ADC EXTERNE EN UTILISANT LES COMMUNICATIONS SPI / I²C are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer CONCEPTION ET DÉVELOPPEMENT D’UN SYSTÈME ANTI-VOL PORTABLE ET MULTI - USAGE À BASE DE CARTE STM32 are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer RÉALISATION D'UN CONTAINER POUR LA RECONNAISSANCE D'IMAGES ET DU TEXTE POUR LES APPLICATIONS ANDROID EMBARQUÉ are:
#   - CV 3993 with similarity score 0.16666666666666666
#   - CV 3986 with similarity score 0.15294382258037448
#   - CV 4080 with similarity score 0.15294382258037448
#   - CV 4032 with similarity score 0.15294382258037448
#   - CV 4155 with similarity score 0.14907119849998596
# The top 5 matches for internship offer DÉVELOPPEMENT D’UNE PROCÉDURE DE GESTION DIGITALE DES CLÉS ET ADRESSE IO POUR LES PRODUITS ÉLECTRONIQUES are:
#   - CV 3993 with similarity score 0.16666666666666666
#   - CV 3986 with similarity score 0.15294382258037448
#   - CV 4080 with similarity score 0.15294382258037448
#   - CV 4032 with similarity score 0.15294382258037448
#   - CV 4155 with similarity score 0.14907119849998596
# The top 5 matches for internship offer IMPLÉMENTATION D'UNE PLATEFORME DE CONTRÔLE À DISTANCE DES DONNÉES CLIMATIQUES D’UNE FERME are:
#   - CV 5560 with similarity score 0.7071067811865475
#   - CV 5474 with similarity score 0.7071067811865475
#   - CV 5423 with similarity score 0.7071067811865475
#   - CV 5173 with similarity score 0.7071067811865475
#   - CV 5178 with similarity score 0.5773502691896258
# The top 5 matches for internship offer CONFIGURATION À DISTANCE DES IPS STM32 are:
#   - CV 5174 with similarity score 0.816496580927726
#   - CV 4932 with similarity score 0.7745966692414834
#   - CV 4772 with similarity score 0.7745966692414834
#   - CV 4647 with similarity score 0.7071067811865477
#   - CV 4627 with similarity score 0.7071067811865477
# The top 5 matches for internship offer SOLUTION DE MISE À JOUR D'UN "TRUSTED FIRMWARE" POUR STM32 are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer MISE EN PLACE D’UNE SOLUTION DE COMMUNICATION V2V ET CRÉATION D’UNE APPLICATION RHS ( ROAD HAZARD SIGNALING ) are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer DÉFINITION ET CRÉATION D’UNE ARCHITECTURE LOGICIELLE SOUS LABVIEW POUR LE DÉVELOPPEMENT DES APPLICATIFS INFORMATIQUES DE PRODUCTION are:
#   - CV 4733 with similarity score 0.36514837167011077
#   - CV 5407 with similarity score 0.3333333333333334
#   - CV 5443 with similarity score 0.3333333333333334
#   - CV 5162 with similarity score 0.3333333333333334
#   - CV 5124 with similarity score 0.3333333333333334
# The top 5 matches for internship offer DÉVELOPPEMENT D’UN TESTEUR DE TÉLÉCHARGEMENT GÉNÉRIQUE ET COMPACT POUR LA PRODUCTION DES CARTES ÉLECTRONIQUES are:
#   - CV 4670 with similarity score 0.25819888974716115
#   - CV 5357 with similarity score 0.22360679774997896
#   - CV 4686 with similarity score 0.22360679774997896
#   - CV 4957 with similarity score 0.22360679774997896
#   - CV 4813 with similarity score 0.22360679774997896
# The top 5 matches for internship offer RÉALISATION D’UN MODULE IHM POUR LA COMMANDE D’UN SYSTÈME DE TRANSMISSION VIDÉO EMBARQUÉE D’UN TRAIN are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer CONCEPTION ET DÉVELOPPEMENT D'UN SIMULATEUR SOME/IP ET CAN are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer CONCEPTION ET DÉVELOPPEMENT D'UNE SOLUTION DE CONVERTION ETHERNET/CAN are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Mise en place d’une chaine d’intégration continue CI /CD are:
#   - CV 1313 with similarity score 0.14744195615489716
#   - CV 1435 with similarity score 0.14744195615489716
#   - CV 1408 with similarity score 0.14744195615489716
#   - CV 1063 with similarity score 0.14350946197048195
#   - CV 1452 with similarity score 0.14350946197048195
# The top 5 matches for internship offer Automatisation des provisionnements et administration des clusters Kubernetes are:
#   - CV 4155 with similarity score 0.253546276418555
#   - CV 4139 with similarity score 0.253546276418555
#   - CV 4071 with similarity score 0.253546276418555
#   - CV 4119 with similarity score 0.24743582965269675
#   - CV 4097 with similarity score 0.24743582965269675
# The top 5 matches for internship offer Plateforme de recouvrement are:
#   - CV 3174 with similarity score 0.2727723627949905
#   - CV 3209 with similarity score 0.2672612419124244
#   - CV 3377 with similarity score 0.2672612419124244
#   - CV 3546 with similarity score 0.2672612419124244
#   - CV 3690 with similarity score 0.2672612419124244
# The top 5 matches for internship offer Plateforme de gestion des sinistres are:
#   - CV 3174 with similarity score 0.31622776601683794
#   - CV 3377 with similarity score 0.3098386676965933
#   - CV 3113 with similarity score 0.3098386676965933
#   - CV 3690 with similarity score 0.3098386676965933
#   - CV 3209 with similarity score 0.3098386676965933
# The top 5 matches for internship offer Dématérialisation are:
#   - CV 5336 with similarity score 0.3481553119113957
#   - CV 5184 with similarity score 0.3481553119113957
#   - CV 3421 with similarity score 0.3077287274483319
#   - CV 3873 with similarity score 0.30151134457776363
#   - CV 5182 with similarity score 0.30151134457776363
# The top 5 matches for internship offer Dématérialisation des documents are:
#   - CV 1768 with similarity score 0.17342199390482396
#   - CV 1647 with similarity score 0.1690308509457033
#   - CV 1537 with similarity score 0.1690308509457033
#   - CV 1655 with similarity score 0.1690308509457033
#   - CV 1664 with similarity score 0.1690308509457033
# The top 5 matches for internship offer Mise en place d’une solution des opérations de Machine Learning (MLOps) are:
#   - CV 1435 with similarity score 0.2886751345948129
#   - CV 1408 with similarity score 0.2886751345948129
#   - CV 1313 with similarity score 0.2886751345948129
#   - CV 1063 with similarity score 0.2809757434745082
#   - CV 1178 with similarity score 0.2809757434745082
# The top 5 matches for internship offer Mise en place d’une architecture de stockage et ETL. are:
#   - CV 5474 with similarity score 0.2886751345948129
#   - CV 5423 with similarity score 0.2886751345948129
#   - CV 5173 with similarity score 0.2886751345948129
#   - CV 5560 with similarity score 0.2886751345948129
#   - CV 1753 with similarity score 0.2738612787525831
# The top 5 matches for internship offer Mise en place d’une architecture d’ingénierie. are:
#   - CV 1190 with similarity score 0.33113308926626095
#   - CV 1480 with similarity score 0.33113308926626095
#   - CV 1335 with similarity score 0.33113308926626095
#   - CV 1058 with similarity score 0.33113308926626095
#   - CV 1452 with similarity score 0.33113308926626095
# The top 5 matches for internship offer Mise en place d’un système d’automatisation des tests de non-régression avec Sélénium are:
#   - CV 1212 with similarity score 0.125
#   - CV 1121 with similarity score 0.12126781251816648
#   - CV 1330 with similarity score 0.12126781251816648
#   - CV 1088 with similarity score 0.12126781251816648
#   - CV 1284 with similarity score 0.11785113019775793
# The top 5 matches for internship offer Etude de l’impact du télétravail sur la santé mentale. are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Elaboration de démarche RSE avec un focus sur le volet RH. are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Réalisation d’une étude qualitative/ quantitative pour évaluer le marché potentiel d’une nouvelle solution digitale dans le secteur de l’assurance transport are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Elaboration d’une stratégie de Branding/ marketing digital pour le lancement d’une nouvelle solution digitale dans le secteur de l’assurance transport. are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Elaboration d’une stratégie de Branding/ marketing digital pour ADDINN Group dans le cadre de sa stratégie de filialisation et de spécialisation. are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Elaboration d’une stratégie de Branding/ marketing digital pour une nouvelle application web/ mobile pour le développement des soft skills en entreprise. are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Conception et développement d’une application mobile pour la gestion des processus de module production et module de stock par lecture code à barre, en le synchronisant avec Dynamics 365 Business Central / Finance and Opérations are:
#   - CV 5560 with similarity score 0.19611613513818402
#   - CV 5474 with similarity score 0.19611613513818402
#   - CV 5423 with similarity score 0.19611613513818402
#   - CV 5173 with similarity score 0.19611613513818402
#   - CV 5178 with similarity score 0.16012815380508716
# The top 5 matches for internship offer Implémentation d'un module de taxes par pays au niveau de Dynamics 365 Finance and Opérations are:
#   - CV 5560 with similarity score 0.2886751345948129
#   - CV 5474 with similarity score 0.2886751345948129
#   - CV 5423 with similarity score 0.2886751345948129
#   - CV 5173 with similarity score 0.2886751345948129
#   - CV 5178 with similarity score 0.2357022603955159
# The top 5 matches for internship offer Traitement des rapports Power BI autour de Dynamics 365 Finance and Opérations are:
#   - CV 1583 with similarity score 0.10540925533894599
#   - CV 1512 with similarity score 0.10540925533894599
#   - CV 1768 with similarity score 0.1025978352085154
#   - CV 1755 with similarity score 0.1025978352085154
#   - CV 1567 with similarity score 0.1025978352085154
# The top 5 matches for internship offer Développement d’un portail d'offres d'emploi/ candidature lié à Dynamics 365 Finance and Opérations are:
#   - CV 5204 with similarity score 0.3333333333333333
#   - CV 4719 with similarity score 0.3333333333333333
#   - CV 5391 with similarity score 0.3333333333333333
#   - CV 4702 with similarity score 0.3333333333333333
#   - CV 5569 with similarity score 0.2981423969999719
# The top 5 matches for internship offer Implémentation d'une solution de détection de caractères basée sur des algorithmes OCR dans une solution web de gestion des notes de frais are:
#   - CV 4702 with similarity score 0.5303300858899106
#   - CV 3882 with similarity score 0.4714045207910316
#   - CV 5325 with similarity score 0.4330127018922194
#   - CV 5026 with similarity score 0.4330127018922194
#   - CV 3937 with similarity score 0.4330127018922194
# The top 5 matches for internship offer mplémentation d’un mode d’authentification unique (SSO) basé sur Microsoft Active Directory dans une solution web existante are:
#   - CV 4702 with similarity score 0.45226701686664544
#   - CV 3882 with similarity score 0.40201512610368484
#   - CV 5026 with similarity score 0.36927447293799825
#   - CV 5012 with similarity score 0.36927447293799825
#   - CV 5436 with similarity score 0.36927447293799825
# The top 5 matches for internship offer Développement d'une application Microsoft Power Apps avec des composants personnalisables, basée sur le langage TypeScript are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Intégration du module « Gestion et comptabilité des projets » de Dynamics 365 Finance and Operations are:
#   - CV 5200 with similarity score 0.31622776601683794
#   - CV 5115 with similarity score 0.282842712474619
#   - CV 4977 with similarity score 0.25819888974716115
#   - CV 4857 with similarity score 0.25819888974716115
#   - CV 5496 with similarity score 0.23904572186687872
# The top 5 matches for internship offer Intégration du module « Gestion de la qualité » de Dynamics 365 Finance and Operations dans les processus de la chaine logistique are:
#   - CV 5200 with similarity score 0.31622776601683794
#   - CV 5115 with similarity score 0.282842712474619
#   - CV 4977 with similarity score 0.25819888974716115
#   - CV 4857 with similarity score 0.25819888974716115
#   - CV 5496 with similarity score 0.23904572186687872
# The top 5 matches for internship offer Analyse prérequis, plan d'action en interne pour la mise en place de la démarche qualité ISO 9001 au sein de la société Aiventu are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Analyse financière prévisionnelle et réelle d'une entreprise à travers Microsoft Dynamics 365 Finance and Opérations are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Intégration du module « Asset Leasing » de Dynamics 365 Finance and Opérations are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Développement d’une application de gestion d'Energie basée sur la plateforme TIA PORTAL Supervision des variables process à distance via le web Server de l’automate S7-1200 are:
#   - CV 5531 with similarity score 0.21320071635561041
#   - CV 5282 with similarity score 0.21320071635561041
#   - CV 5254 with similarity score 0.17407765595569785
#   - CV 5160 with similarity score 0.17407765595569785
#   - CV 5329 with similarity score 0.17407765595569785
# The top 5 matches for internship offer Conception des rapports énergétiques et leurs génération automatique en utilisant TIA PORTAL are:
#   - CV 5329 with similarity score 0.3202563076101743
#   - CV 5238 with similarity score 0.3202563076101743
#   - CV 5003 with similarity score 0.2773500981126146
#   - CV 4632 with similarity score 0.2773500981126146
#   - CV 5288 with similarity score 0.2773500981126146
# The top 5 matches for internship offer Acquisition des données énergétiques avec ARDUINO/ STM32 et envoi vers une application web et mobile are:
#   - CV 5329 with similarity score 0.3086066999241839
#   - CV 5238 with similarity score 0.3086066999241839
#   - CV 5003 with similarity score 0.2672612419124244
#   - CV 4632 with similarity score 0.2672612419124244
#   - CV 5288 with similarity score 0.2672612419124244
# The top 5 matches for internship offer Etude et Programmation d’une application de gestion d’entrainement à base de deux servo-moteurs avec synchronisation software via un système de positionnement à code à barres avec automate Siemens S7-1500 are:
#   - CV 5531 with similarity score 0.2357022603955158
#   - CV 5282 with similarity score 0.2357022603955158
#   - CV 5254 with similarity score 0.19245008972987526
#   - CV 5160 with similarity score 0.19245008972987526
#   - CV 5329 with similarity score 0.19245008972987526
# The top 5 matches for internship offer Développement d’une application de supervision d’une usine complète avec Siemens WinCC are:
#   - CV 5531 with similarity score 0.2357022603955158
#   - CV 5282 with similarity score 0.2357022603955158
#   - CV 5254 with similarity score 0.19245008972987526
#   - CV 5160 with similarity score 0.19245008972987526
#   - CV 5329 with similarity score 0.19245008972987526
# The top 5 matches for internship offer Programmation et simulation d’une cellule robotisée pour empilage et dépilage are:
#   - CV 5531 with similarity score 0.3162277660168379
#   - CV 5282 with similarity score 0.3162277660168379
#   - CV 5254 with similarity score 0.25819888974716115
#   - CV 5160 with similarity score 0.25819888974716115
#   - CV 5329 with similarity score 0.25819888974716115
# The top 5 matches for internship offer Conception et réalisation d’une machine détorsadage des fils pour câbles de l'industrie automobile are:
#   - CV 5531 with similarity score 0.24999999999999994
#   - CV 5282 with similarity score 0.24999999999999994
#   - CV 5254 with similarity score 0.2041241452319315
#   - CV 5160 with similarity score 0.2041241452319315
#   - CV 5329 with similarity score 0.2041241452319315
# The top 5 matches for internship offer Conception d’une machine d’insertion automatique avec changement automatique des gabarits are:
#   - CV 5531 with similarity score 0.2357022603955158
#   - CV 5282 with similarity score 0.2357022603955158
#   - CV 5254 with similarity score 0.19245008972987526
#   - CV 5160 with similarity score 0.19245008972987526
#   - CV 5329 with similarity score 0.19245008972987526
# The top 5 matches for internship offer Etude et conception d’une machine de vissage avec changeur d’outil automatique are:
#   - CV 5531 with similarity score 0.2357022603955158
#   - CV 5282 with similarity score 0.2357022603955158
#   - CV 5254 with similarity score 0.19245008972987526
#   - CV 5160 with similarity score 0.19245008972987526
#   - CV 5329 with similarity score 0.19245008972987526
# The top 5 matches for internship offer Etude et conception d’une machine d’assemblage avec un plateau tournant are:
#   - CV 5531 with similarity score 0.2357022603955158
#   - CV 5282 with similarity score 0.2357022603955158
#   - CV 5254 with similarity score 0.19245008972987526
#   - CV 5160 with similarity score 0.19245008972987526
#   - CV 5329 with similarity score 0.19245008972987526
# The top 5 matches for internship offer Etude et conception d’une machine d'emballage verticale, remplissage et de scellage are:
#   - CV 5531 with similarity score 0.2357022603955158
#   - CV 5282 with similarity score 0.2357022603955158
#   - CV 5254 with similarity score 0.19245008972987526
#   - CV 5160 with similarity score 0.19245008972987526
#   - CV 5329 with similarity score 0.19245008972987526
# The top 5 matches for internship offer Etude et conception d’imprimante 3D à 5 axes are:
#   - CV 5531 with similarity score 0.26726124191242434
#   - CV 5282 with similarity score 0.26726124191242434
#   - CV 5254 with similarity score 0.2182178902359924
#   - CV 5160 with similarity score 0.2182178902359924
#   - CV 5329 with similarity score 0.2182178902359924
# The top 5 matches for internship offer IMPLÉMENTATION D’UNE PLATEFORME D’ANALYSE D'AUDIENCE/TRAFIC WEB (, ReactJS, Typescript, MongoDB) are:
#   - CV 1758 with similarity score 0.10286889997472795
#   - CV 1754 with similarity score 0.10012523486435176
#   - CV 1671 with similarity score 0.10012523486435176
#   - CV 1557 with similarity score 0.10012523486435176
#   - CV 1655 with similarity score 0.09759000729485331
# The top 5 matches for internship offer MACRO-ECONOMIC FORECASTING AND MODELLING are:
#   - CV 1835 with similarity score 0.29704426289300234
#   - CV 1812 with similarity score 0.2809757434745082
#   - CV 1821 with similarity score 0.2738612787525831
#   - CV 1822 with similarity score 0.2672612419124244
#   - CV 1806 with similarity score 0.2672612419124244
# The top 5 matches for internship offer NEURAL NETWORKS EXPLANATION AND RULE EXTRACTIO are:
#   - CV 1835 with similarity score 0.5144957554275265
#   - CV 1812 with similarity score 0.4866642633922876
#   - CV 1821 with similarity score 0.4743416490252569
#   - CV 1822 with similarity score 0.46291004988627577
#   - CV 1806 with similarity score 0.46291004988627577
# The top 5 matches for internship offer MLOPS - CREDIT SCORING MODELING AND MONITORING are:
#   - CV 1835 with similarity score 0.42008402520840293
#   - CV 1812 with similarity score 0.39735970711951313
#   - CV 1821 with similarity score 0.38729833462074176
#   - CV 1806 with similarity score 0.3779644730092272
#   - CV 1822 with similarity score 0.3779644730092272
# The top 5 matches for internship offer TABLE EXTRACTION AND STRUCTURE RECOGNITION are:
#   - CV 3993 with similarity score 0.08333333333333333
#   - CV 4361 with similarity score 0.08084520834544431
#   - CV 4325 with similarity score 0.08084520834544431
#   - CV 4475 with similarity score 0.08084520834544431
#   - CV 4462 with similarity score 0.07856742013183862
# The top 5 matches for internship offer RULE BASED INFORMATION EXTRACTION FROM SEMI STRUCTURED DOCUMENTS are:
#   - CV 4475 with similarity score 0.14625448482542613
#   - CV 4463 with similarity score 0.1421338109037403
#   - CV 4284 with similarity score 0.13834289277321493
#   - CV 4540 with similarity score 0.13483997249264842
#   - CV 4212 with similarity score 0.13483997249264842
# The top 5 matches for internship offer TEXT SEGMENTATION INTO COHERENT PARTS SUCH US PARAGRAPH, TOPIC are:
#   - CV 1796 with similarity score 0.0890870806374748
#   - CV 1827 with similarity score 0.08606629658238703
#   - CV 1804 with similarity score 0.08606629658238703
#   - CV 1805 with similarity score 0.08606629658238703
#   - CV 3993 with similarity score 0.08333333333333333
# The top 5 matches for internship offer DOCUMENT LEVEL SENTIMENT MODELING are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer NEWS ARTICLES RECOMMENDATION MODELING are:
#   - CV 1796 with similarity score 0.0890870806374748
#   - CV 1827 with similarity score 0.08606629658238703
#   - CV 1804 with similarity score 0.08606629658238703
#   - CV 1805 with similarity score 0.08606629658238703
#   - CV 3993 with similarity score 0.08333333333333333
# The top 5 matches for internship offer COLLATERAL MANAGEMENT AND ANALYSIS are:
#   - CV 5420 with similarity score 0.3973597071195132
#   - CV 4825 with similarity score 0.3973597071195132
#   - CV 1657 with similarity score 0.3504383220252312
#   - CV 1765 with similarity score 0.3504383220252312
#   - CV 5248 with similarity score 0.3441236008058426
# The top 5 matches for internship offer ACP FINANCIAL ANALYSIS AND FORECASTING are:
#   - CV 4983 with similarity score 0.5
#   - CV 4705 with similarity score 0.5
#   - CV 5364 with similarity score 0.5
#   - CV 5044 with similarity score 0.5
#   - CV 4771 with similarity score 0.4472135954999579
# The top 5 matches for internship offer BENCHMARKING – PEER ANALYSIS are:
#   - CV 4983 with similarity score 0.5
#   - CV 4705 with similarity score 0.5
#   - CV 5364 with similarity score 0.5
#   - CV 5044 with similarity score 0.5
#   - CV 4771 with similarity score 0.4472135954999579
# The top 5 matches for internship offer COVENANT MANAGEMENT are:
#   - CV 4983 with similarity score 0.5
#   - CV 4705 with similarity score 0.5
#   - CV 5364 with similarity score 0.5
#   - CV 5044 with similarity score 0.5
#   - CV 4771 with similarity score 0.4472135954999579
# The top 5 matches for internship offer ACP SCORING are:
#   - CV 4983 with similarity score 0.5
#   - CV 4705 with similarity score 0.5
#   - CV 5364 with similarity score 0.5
#   - CV 5044 with similarity score 0.5
#   - CV 4771 with similarity score 0.4472135954999579
# The top 5 matches for internship offer COUNTERPARTY STRUCTURE are:
#   - CV 3931 with similarity score 0.5000000000000001
#   - CV 4983 with similarity score 0.4082482904638631
#   - CV 3873 with similarity score 0.4082482904638631
#   - CV 5364 with similarity score 0.4082482904638631
#   - CV 4705 with similarity score 0.4082482904638631
# The top 5 matches for internship offer LOAN ORIGINATION PROCESS AUTOMATION are:
#   - CV 3931 with similarity score 0.5000000000000001
#   - CV 4983 with similarity score 0.4082482904638631
#   - CV 3873 with similarity score 0.4082482904638631
#   - CV 5364 with similarity score 0.4082482904638631
#   - CV 4705 with similarity score 0.4082482904638631
# The top 5 matches for internship offer ADVANCED LOAN SERVICING FEATURES are:
#   - CV 3931 with similarity score 0.4330127018922194
#   - CV 4983 with similarity score 0.35355339059327373
#   - CV 3873 with similarity score 0.35355339059327373
#   - CV 5364 with similarity score 0.35355339059327373
#   - CV 4705 with similarity score 0.35355339059327373
# The top 5 matches for internship offer DOCUMENT MANAGEMENT CAPABILITIES are:
#   - CV 3931 with similarity score 0.5000000000000001
#   - CV 4983 with similarity score 0.4082482904638631
#   - CV 3873 with similarity score 0.4082482904638631
#   - CV 5364 with similarity score 0.4082482904638631
#   - CV 4705 with similarity score 0.4082482904638631
# The top 5 matches for internship offer FRR are:
#   - CV 4983 with similarity score 0.5
#   - CV 4705 with similarity score 0.5
#   - CV 5364 with similarity score 0.5
#   - CV 5044 with similarity score 0.5
#   - CV 4771 with similarity score 0.4472135954999579
# The top 5 matches for internship offer AXE IDENTITY AND ACCESS MANAGEMENT are:
#   - CV 3931 with similarity score 0.2886751345948129
#   - CV 4983 with similarity score 0.23570226039551587
#   - CV 3873 with similarity score 0.23570226039551587
#   - CV 5364 with similarity score 0.23570226039551587
#   - CV 4705 with similarity score 0.23570226039551587
# The top 5 matches for internship offer RESTITUTION OF DASHBOARD ANALYZING AZURE DEVOPS BOARD ACTIVITY are:
#   - CV 5420 with similarity score 0.37796447300922725
#   - CV 4825 with similarity score 0.37796447300922725
#   - CV 1765 with similarity score 0.33333333333333337
#   - CV 1657 with similarity score 0.33333333333333337
#   - CV 5248 with similarity score 0.3273268353539886
# The top 5 matches for internship offer AUTOMATE ON-PREMISE DEPLOYMENT OF .NET CONTAINERIZED APPLICATIONS USING CI/CD PIPELINES are:
#   - CV 4521 with similarity score 0.2773500981126146
#   - CV 4581 with similarity score 0.2721655269759087
#   - CV 4209 with similarity score 0.2721655269759087
#   - CV 4577 with similarity score 0.2721655269759087
#   - CV 4554 with similarity score 0.26726124191242434
# The top 5 matches for internship offer UX/UI MOBILE APPLICATION MYACP are:
#   - CV 3174 with similarity score 0.3689323936863109
#   - CV 2968 with similarity score 0.3689323936863109
#   - CV 5082 with similarity score 0.36514837167011066
#   - CV 3114 with similarity score 0.3614784456460255
#   - CV 3469 with similarity score 0.3614784456460255
# The top 5 matches for internship offer REAL-TIME COMMUNICATION APPLICATIONS are:
#   - CV 3913 with similarity score 0.5039526306789696
#   - CV 1964 with similarity score 0.39999999999999997
#   - CV 2503 with similarity score 0.392232270276368
#   - CV 2520 with similarity score 0.392232270276368
#   - CV 5025 with similarity score 0.3849001794597505
# The top 5 matches for internship offer LIMIT MANAGEMENT MOBILE APP are:
#   - CV 3913 with similarity score 0.47809144373375745
#   - CV 1964 with similarity score 0.3794733192202056
#   - CV 2503 with similarity score 0.3721042037676254
#   - CV 2520 with similarity score 0.3721042037676254
#   - CV 5025 with similarity score 0.3651483716701108
# The top 5 matches for internship offer API STANDARD CONNECTOR are:
#   - CV 4970 with similarity score 0.3333333333333334
#   - CV 5100 with similarity score 0.3333333333333334
#   - CV 4744 with similarity score 0.3333333333333334
#   - CV 5433 with similarity score 0.3333333333333334
#   - CV 5184 with similarity score 0.3333333333333334
# The top 5 matches for internship offer TIMESHEET MANAGEMENT are:
#   - CV 5184 with similarity score 0.5163977794943223
#   - CV 5336 with similarity score 0.5163977794943223
#   - CV 5182 with similarity score 0.4472135954999579
#   - CV 3873 with similarity score 0.4472135954999579
#   - CV 5359 with similarity score 0.4472135954999579
# The top 5 matches for internship offer AZURE - DEVOPS are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer AUTOMATING LOAN CALCULATOR TESTING are:
#   - CV 4918 with similarity score 0.7071067811865475
#   - CV 5136 with similarity score 0.7071067811865475
#   - CV 5174 with similarity score 0.7071067811865475
#   - CV 5352 with similarity score 0.7071067811865475
#   - CV 4909 with similarity score 0.5773502691896258
# The top 5 matches for internship offer  PRICING GUIDELINES SYSTEM are:
#   - CV 41 with similarity score 0.13245323570650439
#   - CV 384 with similarity score 0.12909944487358058
#   - CV 830 with similarity score 0.12909944487358058
#   - CV 865 with similarity score 0.12909944487358058
#   - CV 950 with similarity score 0.12909944487358058
# The top 5 matches for internship offer ALTERNATIVE BORROWER RISK RATING MODEL are:
#   - CV 41 with similarity score 0.13245323570650439
#   - CV 384 with similarity score 0.12909944487358058
#   - CV 830 with similarity score 0.12909944487358058
#   - CV 865 with similarity score 0.12909944487358058
#   - CV 950 with similarity score 0.12909944487358058
# The top 5 matches for internship offer CONSTRUCTION AND REAL ESTATE RATING MODEL are:
#   - CV 41 with similarity score 0.13245323570650439
#   - CV 384 with similarity score 0.12909944487358058
#   - CV 830 with similarity score 0.12909944487358058
#   - CV 865 with similarity score 0.12909944487358058
#   - CV 950 with similarity score 0.12909944487358058
# The top 5 matches for internship offer SHAREHOLDING AND DIRECTOR INTEGRATION API are:
#   - CV 5204 with similarity score 0.5
#   - CV 4719 with similarity score 0.5
#   - CV 5391 with similarity score 0.5
#   - CV 4702 with similarity score 0.5
#   - CV 5569 with similarity score 0.4472135954999579
# The top 5 matches for internship offer HUMAN RESOURCES (HR) INTERNSHIP are:
#   - CV 5396 with similarity score 0.2981423969999719
#   - CV 5020 with similarity score 0.2981423969999719
#   - CV 4609 with similarity score 0.2981423969999719
#   - CV 4607 with similarity score 0.2981423969999719
#   - CV 5243 with similarity score 0.2981423969999719
# The top 5 matches for internship offer AUTOMATIC LEAD SCORING AND MANAGEMENT THROUGH ACP WORKFLOWS are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer HELPDESK APPLICATION are:
#   - CV 5395 with similarity score 0.5773502691896258
#   - CV 5231 with similarity score 0.5163977794943223
#   - CV 5161 with similarity score 0.4714045207910318
#   - CV 4754 with similarity score 0.4714045207910318
#   - CV 5495 with similarity score 0.4714045207910318
# The top 5 matches for internship offer DEEP LEARNING IN THE AUTOMOTIVE INDUSTRY are:
#   - CV 1839 with similarity score 0.5128225940683708
#   - CV 1833 with similarity score 0.4962916669854651
#   - CV 1800 with similarity score 0.4717281765248633
#   - CV 1834 with similarity score 0.4466625002869186
#   - CV 1795 with similarity score 0.4458225700602823
# The top 5 matches for internship offer OFFERS RECOMMENDATIONS FOR NEARBY CAR DRIVERS are:
#   - CV 5497 with similarity score 0.408248290463863
#   - CV 5253 with similarity score 0.408248290463863
#   - CV 5170 with similarity score 0.408248290463863
#   - CV 5491 with similarity score 0.3333333333333334
#   - CV 5336 with similarity score 0.3333333333333334
# The top 5 matches for internship offer EXTERIOR LIGHTING SYSTEM PROTOTYPE FOR A CAR are:
#   - CV 3993 with similarity score 0.07216878364870323
#   - CV 1758 with similarity score 0.06804138174397718
#   - CV 4067 with similarity score 0.06804138174397718
#   - CV 4154 with similarity score 0.06622661785325219
#   - CV 4083 with similarity score 0.06622661785325219
# The top 5 matches for internship offer STUDY, DESIGN AND PRODUCTION OF THE BMS FOR A 24V LITHIUM-ION BATTERY are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer STUDY AND DEVELOPMENT OF AN ELECTROMAGNETIC SIMULATOR FOR LITHIUM-ION BATTERIES OF AN ELECTRIC VEHICLE are:
#   - CV 4738 with similarity score 0.408248290463863
#   - CV 4947 with similarity score 0.408248290463863
#   - CV 5462 with similarity score 0.408248290463863
#   - CV 5102 with similarity score 0.408248290463863
#   - CV 4987 with similarity score 0.408248290463863
# The top 5 matches for internship offer STUDY AND ANALYSIS OF FAST AND ULTRA-FAST CHARGING TECHNIQUES FOR ELECTRIC VEHICLES are:
#   - CV 4738 with similarity score 0.2886751345948129
#   - CV 4947 with similarity score 0.2886751345948129
#   - CV 5462 with similarity score 0.2886751345948129
#   - CV 5102 with similarity score 0.2886751345948129
#   - CV 4987 with similarity score 0.2886751345948129
# The top 5 matches for internship offer PROOF OF CONCEPT (PROTOTYPE) OF A V2V COMMUNICATION SOLUTIONS / V2V NETWORK are:
#   - CV 3174 with similarity score 0.19611613513818407
#   - CV 3421 with similarity score 0.19611613513818407
#   - CV 3139 with similarity score 0.1921537845661046
#   - CV 2994 with similarity score 0.1921537845661046
#   - CV 3546 with similarity score 0.1921537845661046
# The top 5 matches for internship offer DEVELOPMENT OF A BI SOLUTION BASED ON MACHINE LEARNING TECHNOLOGIES are:
#   - CV 1800 with similarity score 0.38074980525429486
#   - CV 1833 with similarity score 0.36051834183722337
#   - CV 1851 with similarity score 0.34668762264076824
#   - CV 1826 with similarity score 0.3396831102433787
#   - CV 1835 with similarity score 0.3363363969981562
# The top 5 matches for internship offer DESIGN OF A 120W USB PD EXTERNAL POWER SUPPLY are:
#   - CV 4325 with similarity score 0.07312724241271307
#   - CV 4475 with similarity score 0.07312724241271307
#   - CV 4361 with similarity score 0.07312724241271307
#   - CV 4462 with similarity score 0.07106690545187015
#   - CV 4294 with similarity score 0.07106690545187015
# The top 5 matches for internship offer DESIGN AND DEVELOPMENT OF A SYSTEM IMAGE THROUGH YOCTO RUNNING ON THE RASPBERRY PI PLATFORM AND PROVIDE THE SDK TO INTEGRATE AN APPLICATION WITH QT are:
#   - CV 5094 with similarity score 0.1825741858350554
#   - CV 4795 with similarity score 0.1825741858350554
#   - CV 5535 with similarity score 0.15811388300841897
#   - CV 4998 with similarity score 0.15811388300841897
#   - CV 4694 with similarity score 0.15811388300841897
# The top 5 matches for internship offer STUDY AND DESIGN OF AN INTELLIGENT CHARGER FOR LITHIUM-ION BATTERY are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer AUTOSAR CAN/ ETHERNET HYBRID GATEWAY USING SOME/IP (SCALABLE SERVICE-ORIENTED MIDDLEWARE OVER IP) are:
#   - CV 5274 with similarity score 0.3162277660168379
#   - CV 5456 with similarity score 0.3162277660168379
#   - CV 4589 with similarity score 0.3162277660168379
#   - CV 5334 with similarity score 0.3162277660168379
#   - CV 5300 with similarity score 0.25819888974716115
# The top 5 matches for internship offer GRAPHICS SHARING BETWEEN ANDROID DEVICE AND RASPBERRY PI MODULE THROUGH BLUETOOTH are:
#   - CV 5435 with similarity score 0.4330127018922194
#   - CV 5017 with similarity score 0.35355339059327384
#   - CV 5547 with similarity score 0.3333333333333334
#   - CV 5038 with similarity score 0.3333333333333334
#   - CV 4868 with similarity score 0.3333333333333334
# The top 5 matches for internship offer INSTALLATION OF A MOBILE RADAR ROBOT are:
#   - CV 5174 with similarity score 0.2357022603955158
#   - CV 5352 with similarity score 0.2357022603955158
#   - CV 5136 with similarity score 0.2357022603955158
#   - CV 4918 with similarity score 0.2357022603955158
#   - CV 5072 with similarity score 0.19245008972987526
# The top 5 matches for internship offer DESIGN AND IMPLEMENTATION OF A MERCHANDISE RECOGNITION MODULE are:
#   - CV 5174 with similarity score 0.2357022603955158
#   - CV 5352 with similarity score 0.2357022603955158
#   - CV 5136 with similarity score 0.2357022603955158
#   - CV 4918 with similarity score 0.2357022603955158
#   - CV 5072 with similarity score 0.19245008972987526
# The top 5 matches for internship offer ROLL-UP PAGE SCANNING SYSTEM PROTOTYPE are:
#   - CV 5174 with similarity score 0.2357022603955158
#   - CV 5352 with similarity score 0.2357022603955158
#   - CV 5136 with similarity score 0.2357022603955158
#   - CV 4918 with similarity score 0.2357022603955158
#   - CV 5072 with similarity score 0.19245008972987526
# The top 5 matches for internship offer DEVELOPMENT OF AN AUTOMATED "MATCHING" SYSTEM BETWEEN CV AND JOB OFFERS (LOT2) are:
#   - CV 5427 with similarity score 0.4338609156373123
#   - CV 1842 with similarity score 0.4136701519960152
#   - CV 1855 with similarity score 0.40457738993933884
#   - CV 1786 with similarity score 0.3960590171906698
#   - CV 4777 with similarity score 0.39605901719066977
# The top 5 matches for internship offer DEVELOPMENT AND DESIGN OF A PLATFORM FOR THE DISSEMINATION OF EVENTS (TRAINING, COMMUNICATIONS, OTHER) ORGANIZED WITHIN CAPGEMINI are:
#   - CV 4685 with similarity score 0.4082482904638631
#   - CV 4858 with similarity score 0.4082482904638631
#   - CV 5250 with similarity score 0.4082482904638631
#   - CV 5231 with similarity score 0.36514837167011077
#   - CV 4973 with similarity score 0.36514837167011077
# The top 5 matches for internship offer SHARING KNOWLEDGE PLATFORM are:
#   - CV 2355 with similarity score 0.5819143739626463
#   - CV 2205 with similarity score 0.5714285714285713
#   - CV 5455 with similarity score 0.5669467095138407
#   - CV 4804 with similarity score 0.5669467095138407
#   - CV 5394 with similarity score 0.5669467095138407
# The top 5 matches for internship offer DESIGN AND IMPLEMENTATION OF A DOCUMENT MANAGEMENT SYSTEM are:
#   - CV 5517 with similarity score 0.7745966692414834
#   - CV 4815 with similarity score 0.6708203932499369
#   - CV 4851 with similarity score 0.6
#   - CV 4636 with similarity score 0.5477225575051662
#   - CV 5507 with similarity score 0.5477225575051662
# The top 5 matches for internship offer HUMAN RESOURCE MANAGEMENT APPLICATION are:
#   - CV 4849 with similarity score 0.5163977794943223
#   - CV 4680 with similarity score 0.5163977794943223
#   - CV 4685 with similarity score 0.4743416490252569
#   - CV 5253 with similarity score 0.4472135954999579
#   - CV 5536 with similarity score 0.4242640687119285
# The top 5 matches for internship offer MOBILE DEVELOPER are:
#   - CV 4830 with similarity score 0.22360679774997896
#   - CV 5001 with similarity score 0.22360679774997896
#   - CV 5560 with similarity score 0.22360679774997896
#   - CV 2063 with similarity score 0.18973665961010278
#   - CV 2597 with similarity score 0.18973665961010278
# The top 5 matches for internship offer BUSINESS ANALYST are:
#   - CV 4830 with similarity score 0.24999999999999994
#   - CV 5001 with similarity score 0.24999999999999994
#   - CV 5560 with similarity score 0.24999999999999994
#   - CV 2597 with similarity score 0.21213203435596426
#   - CV 2063 with similarity score 0.21213203435596426
# The top 5 matches for internship offer Deploy an Occupancy Analytics Solution at the Edge are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Development of a Smart Attendance System are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer AI Solution for early fire detection are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Design of a Smart Queuing System are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Advanced home security using object detection are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Embedded Machine Learning Solutions for ATM Security are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Develop an Entreprise-Grade Edge AI server are:
#   - CV 1261 with similarity score 0.23570226039551587
#   - CV 1295 with similarity score 0.23570226039551587
#   - CV 1452 with similarity score 0.22941573387056172
#   - CV 1061 with similarity score 0.22941573387056172
#   - CV 1058 with similarity score 0.22941573387056172
# The top 5 matches for internship offer Developing of a digital communication strategy : boosting the visibility of the startup DATADOIT nationally and internationally are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Développement d'un éditeur graphique de workflow are:
#   - CV 5250 with similarity score 0.6708203932499369
#   - CV 4858 with similarity score 0.6708203932499369
#   - CV 4685 with similarity score 0.6708203932499369
#   - CV 4855 with similarity score 0.6324555320336758
#   - CV 5231 with similarity score 0.6
# The top 5 matches for internship offer Application mobile WMS avec prise en charge des modes connecté et déconnecté are:
#   - CV 5362 with similarity score 0.4714045207910318
#   - CV 4742 with similarity score 0.4714045207910318
#   - CV 4881 with similarity score 0.4082482904638631
#   - CV 5149 with similarity score 0.4082482904638631
#   - CV 4657 with similarity score 0.4082482904638631
# The top 5 matches for internship offer  Refonte d’une Application GMAO are:
#   - CV 5250 with similarity score 0.6708203932499369
#   - CV 4858 with similarity score 0.6708203932499369
#   - CV 4685 with similarity score 0.6708203932499369
#   - CV 4855 with similarity score 0.6324555320336758
# ...
#   - CV 5141 with similarity score 0.5
#   - CV 5013 with similarity score 0.5
# The top 5 matches for internship offer Techno Risk 01
#  are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer Techno Risk 02 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer Techno Risk 03 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer Techno Risk 04 are:
#   - CV 4380 with similarity score 0.11547005383792514
#   - CV 4389 with similarity score 0.11180339887498948
#   - CV 4291 with similarity score 0.11180339887498948
#   - CV 4269 with similarity score 0.11180339887498948
#   - CV 4300 with similarity score 0.10846522890932808
# The top 5 matches for internship offer Techno Risk 05 are:
#   - CV 4380 with similarity score 0.11547005383792514
#   - CV 4389 with similarity score 0.11180339887498948
#   - CV 4291 with similarity score 0.11180339887498948
#   - CV 4269 with similarity score 0.11180339887498948
#   - CV 4300 with similarity score 0.10846522890932808
# The top 5 matches for internship offer SOC 01 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer SOC 02 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer SOC 03 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer Cyber 01 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer Cyber 02 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer Cyber 03 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer Cyber 04 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer Cyber 05 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer Cyber 06 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer Cyber 07 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer Cyber 08 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer Cyber 09 are:
#   - CV 4380 with similarity score 0.14907119849998599
#   - CV 4389 with similarity score 0.14433756729740646
#   - CV 4291 with similarity score 0.14433756729740646
#   - CV 4269 with similarity score 0.14433756729740646
#   - CV 4300 with similarity score 0.140028008402801
# The top 5 matches for internship offer Azure Data engineering et reporting , Power BI pour le module RH de l'ERP Stark are:
#   - CV 1753 with similarity score 0.19999999999999998
#   - CV 1765 with similarity score 0.19518001458970663
#   - CV 1739 with similarity score 0.19069251784911845
#   - CV 1839 with similarity score 0.19069251784911845
#   - CV 1584 with similarity score 0.18650096164806276
# The top 5 matches for internship offer Azure Data engineering et reporting , Power BI pour le module Commercial de l'ERP Stark are:
#   - CV 1753 with similarity score 0.19999999999999998
#   - CV 1765 with similarity score 0.19518001458970663
#   - CV 1739 with similarity score 0.19069251784911845
#   - CV 1839 with similarity score 0.19069251784911845
#   - CV 1584 with similarity score 0.18650096164806276
# The top 5 matches for internship offer Développment d'une plateforme RH are:
#   - CV 5256 with similarity score 0.4714045207910318
#   - CV 5297 with similarity score 0.4082482904638631
#   - CV 4642 with similarity score 0.4082482904638631
#   - CV 5524 with similarity score 0.4082482904638631
#   - CV 5090 with similarity score 0.4082482904638631
# The top 5 matches for internship offer Développement d'une application mobile RH are:
#   - CV 5197 with similarity score 0.5773502691896258
#   - CV 5185 with similarity score 0.5773502691896258
#   - CV 5342 with similarity score 0.5
#   - CV 4881 with similarity score 0.5
#   - CV 4976 with similarity score 0.5
# The top 5 matches for internship offer B2B Stark are:
#   - CV 5256 with similarity score 0.4714045207910318
#   - CV 5297 with similarity score 0.4082482904638631
#   - CV 4642 with similarity score 0.4082482904638631
#   - CV 5524 with similarity score 0.4082482904638631
#   - CV 5090 with similarity score 0.4082482904638631
# The top 5 matches for internship offer Migration des bases de données vers PostgreSQL are:
#   - CV 4928 with similarity score 0.5303300858899106
#   - CV 5030 with similarity score 0.5303300858899106
#   - CV 5381 with similarity score 0.47434164902525683
#   - CV 5363 with similarity score 0.4330127018922194
#   - CV 5228 with similarity score 0.408248290463863
# The top 5 matches for internship offer Mise à jour du projet micro-front are:
#   - CV 4639 with similarity score 0.6
#   - CV 5355 with similarity score 0.5477225575051662
#   - CV 5026 with similarity score 0.5477225575051662
#   - CV 3904 with similarity score 0.5163977794943223
#   - CV 5408 with similarity score 0.5163977794943223
# The top 5 matches for internship offer Développment et mise à jour du système de notifications are:
#   - CV 4639 with similarity score 0.6
#   - CV 5355 with similarity score 0.5477225575051662
#   - CV 5026 with similarity score 0.5477225575051662
#   - CV 3904 with similarity score 0.5163977794943223
#   - CV 5408 with similarity score 0.5163977794943223
# The top 5 matches for internship offer Stark comptabilité générale et IFRS are:
#   - CV 5495 with similarity score 0.5000000000000001
#   - CV 5161 with similarity score 0.5000000000000001
#   - CV 3904 with similarity score 0.4714045207910318
#   - CV 5228 with similarity score 0.4714045207910318
#   - CV 4688 with similarity score 0.4082482904638631
# The top 5 matches for internship offer stark authentification are:
#   - CV 5495 with similarity score 0.5000000000000001
#   - CV 5161 with similarity score 0.5000000000000001
#   - CV 3904 with similarity score 0.4714045207910318
#   - CV 5228 with similarity score 0.4714045207910318
#   - CV 4688 with similarity score 0.4082482904638631
# The top 5 matches for internship offer CRM et Marketing are:
#   - CV 5495 with similarity score 0.5000000000000001
#   - CV 5161 with similarity score 0.5000000000000001
#   - CV 3904 with similarity score 0.4714045207910318
#   - CV 5228 with similarity score 0.4714045207910318
#   - CV 4688 with similarity score 0.4082482904638631
# The top 5 matches for internship offer Job Finder are:
#   - CV 5495 with similarity score 0.5000000000000001
#   - CV 5161 with similarity score 0.5000000000000001
#   - CV 3904 with similarity score 0.4714045207910318
#   - CV 5228 with similarity score 0.4714045207910318
#   - CV 4688 with similarity score 0.4082482904638631
# The top 5 matches for internship offer Module production are:
#   - CV 5495 with similarity score 0.5000000000000001
#   - CV 5161 with similarity score 0.5000000000000001
#   - CV 3904 with similarity score 0.4714045207910318
#   - CV 5228 with similarity score 0.4714045207910318
#   - CV 4688 with similarity score 0.4082482904638631
# The top 5 matches for internship offer EKYC are:
#   - CV 1835 with similarity score 0.4338609156373123
#   - CV 1812 with similarity score 0.4103913408340616
#   - CV 1821 with similarity score 0.39999999999999997
#   - CV 1823 with similarity score 0.3813850356982369
#   - CV 1848 with similarity score 0.36514837167011077
# The top 5 matches for internship offer AML are:
#   - CV 1835 with similarity score 0.4338609156373123
#   - CV 1812 with similarity score 0.4103913408340616
#   - CV 1821 with similarity score 0.39999999999999997
#   - CV 1823 with similarity score 0.3813850356982369
#   - CV 1848 with similarity score 0.36514837167011077
# The top 5 matches for internship offer Document extractor are:
#   - CV 1835 with similarity score 0.4338609156373123
#   - CV 1812 with similarity score 0.4103913408340616
#   - CV 1821 with similarity score 0.39999999999999997
#   - CV 1823 with similarity score 0.3813850356982369
#   - CV 1848 with similarity score 0.36514837167011077
# The top 5 matches for internship offer Test auto are:
#   - CV 4918 with similarity score 0.3162277660168379
#   - CV 5136 with similarity score 0.3162277660168379
#   - CV 5174 with similarity score 0.3162277660168379
#   - CV 5352 with similarity score 0.3162277660168379
#   - CV 4909 with similarity score 0.25819888974716115
# The top 5 matches for internship offer Sécurité réseaux are:
#   - CV 1224 with similarity score 0.09901475429766744
#   - CV 1401 with similarity score 0.09901475429766744
#   - CV 1330 with similarity score 0.09901475429766744
#   - CV 1242 with similarity score 0.09901475429766744
#   - CV 1154 with similarity score 0.09622504486493764
# The top 5 matches for internship offer Mise en place d'une solution de gestion de tracabilité pour une architecture micro-services are:
#   - CV 5473 with similarity score 0.5163977794943223
#   - CV 4909 with similarity score 0.5163977794943223
#   - CV 5100 with similarity score 0.5163977794943223
#   - CV 5030 with similarity score 0.4472135954999579
#   - CV 5103 with similarity score 0.39999999999999997
# The top 5 matches for internship offer Backup et migration des ressources Kubernetes et des volumes persistents are:
#   - CV 3993 with similarity score 0.125
#   - CV 1291 with similarity score 0.125
#   - CV 1212 with similarity score 0.125
#   - CV 1401 with similarity score 0.12126781251816648
#   - CV 1242 with similarity score 0.12126781251816648
# The top 5 matches for internship offer Provisionnement et exploration des services AWS are:
#   - CV 1224 with similarity score 0.140028008402801
#   - CV 1401 with similarity score 0.140028008402801
#   - CV 1330 with similarity score 0.140028008402801
#   - CV 1242 with similarity score 0.140028008402801
#   - CV 1282 with similarity score 0.13608276348795437
# The top 5 matches for internship offer Provisionnement et exploration des services Azure are:
#   - CV 1224 with similarity score 0.058823529411764705
#   - CV 1121 with similarity score 0.058823529411764705
#   - CV 1330 with similarity score 0.058823529411764705
#   - CV 1242 with similarity score 0.058823529411764705
#   - CV 1401 with similarity score 0.058823529411764705
# The top 5 matches for internship offer UI-UX are:
#   - CV 3421 with similarity score 0.35355339059327384
#   - CV 3174 with similarity score 0.35355339059327384
#   - CV 2968 with similarity score 0.35355339059327384
#   - CV 3114 with similarity score 0.3464101615137755
#   - CV 2994 with similarity score 0.3464101615137755
# The top 5 matches for internship offer Communication digitale sur Stark Solutions are:
#   - CV 5531 with similarity score 0.35355339059327373
#   - CV 5282 with similarity score 0.35355339059327373
#   - CV 5059 with similarity score 0.2886751345948129
#   - CV 5329 with similarity score 0.2886751345948129
#   - CV 4963 with similarity score 0.2886751345948129
# The top 5 matches for internship offer Elaboration d'une stratégie commerciale pour l'ERP Stark are:
#   - CV 4380 with similarity score 0.18257418583505533
#   - CV 4389 with similarity score 0.17677669529663687
#   - CV 4291 with similarity score 0.17677669529663687
#   - CV 4269 with similarity score 0.17677669529663687
#   - CV 4300 with similarity score 0.17149858514250882
# The top 5 matches for internship offer Rédaction web pour le site de Stark Solutions are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Référencement naturel du site-web de Stark Solutions are:
#   - CV 5580 with similarity score 0.0
#   - CV 1862 with similarity score 0.0
#   - CV 1854 with similarity score 0.0
#   - CV 1855 with similarity score 0.0
#   - CV 1856 with similarity score 0.0
# The top 5 matches for internship offer Social media management de Stark Solutions  are:
#   - CV 41 with similarity score 0.08671099695241198
#   - CV 384 with similarity score 0.08451542547285165
#   - CV 830 with similarity score 0.08451542547285165
#   - CV 865 with similarity score 0.08451542547285165
#   - CV 950 with similarity score 0.08451542547285165
# The top 5 matches for internship offer Proposition et conception d'une spécification fonctionnelle pour le module d'ordonnancement des opérations de production  are:
#   - CV 5200 with similarity score 0.4082482904638631
#   - CV 5115 with similarity score 0.36514837167011077
#   - CV 4977 with similarity score 0.3333333333333334
#   - CV 4857 with similarity score 0.3333333333333334
#   - CV 4981 with similarity score 0.3086066999241838
# The top 5 matches for internship offer Proposition et conception d'une spécification fonctionnelle pour le module de réapprovisionnement des articles achetés et fabriqués (Réappro Hors MRP et Réappro CBN) are:
#   - CV 5200 with similarity score 0.4082482904638631
#   - CV 5115 with similarity score 0.36514837167011077
#   - CV 4977 with similarity score 0.3333333333333334
#   - CV 4857 with similarity score 0.3333333333333334
#   - CV 4981 with similarity score 0.3086066999241838
# Accuracy: 0.0017985611510791368

# %% [markdown]
# # Matching using BERT algorithm

# %%
import pandas as pd
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModel



# Load the datasets of end-of-study internships (PFE) and resumes for students

def find_top_matches(cv_skills, model):
    tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
    internships_offers = pd.read_excel('pfe_dataset.xlsx')
    internships_offers["Skills"] = internships_offers["Skills"].apply(lambda x: x.split(",") if isinstance(x, str) else [])
    internships_offers["Skills_str"] = internships_offers["Skills"].apply(lambda x: " ".join(x))
    # Compute the BERT embedding for the skills of the given resume
    cv_skill_embeddings = model(**tokenizer(cv_skills, padding=True, truncation=True, return_tensors="pt")).pooler_output[0].detach().numpy()

    # Calculate the cosine similarity scores
    cosine_similarity_scores = []
    for i in range(len(internships_offers)):
        offer_skill_embeddings = model(**tokenizer(internships_offers["Skills_str"][i], padding=True, truncation=True, return_tensors="pt")).pooler_output[0].detach().numpy()
        cosine_similarity_scores.append(np.dot(offer_skill_embeddings, cv_skill_embeddings.T) / (np.linalg.norm(offer_skill_embeddings) * np.linalg.norm(cv_skill_embeddings)))

    # Sort the similarity scores by descending order
    top_matches_indices = np.argsort(cosine_similarity_scores)[::-1][:5]

    # Print the top 5 matches with the job title and company
    print("The top 5 matches for the given CV are:")
    for i in top_matches_indices:
        job_title = internships_offers.iloc[i]["Title"]
        company = internships_offers.iloc[i]["CompanyName"]
        similarity_score = cosine_similarity_scores[i]
        print(f"- {job_title} at {company} with similarity score {similarity_score}")

# %%
model = AutoModel.from_pretrained('bert-base-uncased')
cv_skills = "Python, Machine Learning, Data Analysis, Problem Solving"
find_top_matches(cv_skills, model)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# The top 5 matches for the given CV are:
# - Bounding box labeling on internal website at DRAXLMAIER with similarity score 0.9966569542884827
# - Object tracking for production settings at DRAXLMAIER with similarity score 0.9966569542884827
# - UX/UI MOBILE APPLICATION MYACP at AxeFinance with similarity score 0.9963304996490479
# - PROOF OF CONCEPT (PROTOTYPE) OF A V2V COMMUNICATION SOLUTIONS / V2V NETWORK at Capgemini with similarity score 0.9960061311721802
# - MLOPS - CREDIT SCORING MODELING AND MONITORING at AxeFinance with similarity score 0.9958928823471069

# %%
pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (4.27.3)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (4.62.3)
# Requirement already satisfied: torch>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (2.0.0)
# Requirement already satisfied: torchvision in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (0.15.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (1.22.4)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (1.7.1)
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (3.6.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-win_amd64.whl (977 kB)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (0.13.3)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.3.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.26.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: packaging>=20.9 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch>=1.6.0->sentence-transformers) (1.9)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch>=1.6.0->sentence-transformers) (2.6.3)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.6.0->sentence-transformers) (2.11.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.8.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\programdata\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (1.1.1)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk->sentence-transformers) (8.0.3)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2021.10.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from torchvision->sentence-transformers) (9.5.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py): started
#   Building wheel for sentence-transformers (setup.py): finished with status 'done'
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=ebb6de09fe678b8e2d68e441a0eacec07008e64fefbcab7d432af690074212d5
#   Stored in directory: c:\users\barki\appdata\local\pip\cache\wheels\71\67\06\162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, sentence-transformers
# Successfully installed sentence-transformers-2.2.2 sentencepiece-0.1.98
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ryptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ryptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ryptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ryptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ryptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ryptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ryptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ckaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -2yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -1yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -0yptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ryptography (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)

# %%
df
# Out:
#                                                  Title  \
# 0    DÉVELOPPEMENT D’UN SYSTÈME D'INFO DIVERTISSEME...
# 1    DÉVELOPPEMENT D’UN OUTIL DE DIAGNOSTIC AVEC IN...
# 2         DÉVELOPPEMENT D’UNE SOLUTION DE DÉBOGAGE OTA
# 3    GPS NMEA GENERATOR FOR TRACKING SYSTEM VIRTUAL...
# 4    CONCEPTION ET DÉVELOPPEMENT D'UN SYSTÈME D'ÉLE...
# ..                                                 ...
# 551      Rédaction web pour le site de Stark Solutions
# 552  Référencement naturel du site-web de Stark Sol...
# 553        Social media management de Stark Solutions
# 554  Proposition et conception d'une spécification ...
# 555  Proposition et conception d'une spécification ...
#
#                                            Description  \
# 0    IMPLÉMENTATION DES FONCTIONNALITÉS ( BLUETOOTH...
# 1    INTERFACE GRAPHIQUE PERMETTANT DE COMMUNIQUER ...
# 2    APPLICATION WEB ET D’UN PROGRAMME C (QUI SERA ...
# 3    IL S'AGIT DE DEVELOPPER UN SIMULTAUER GPS L'AP...
# 4    L'ANALYSE ET CONCEPTION DE LA SOLUTION. - CONV...
# ..                                                 ...
# 551  Proposition des améliorations sur le site web ...
# 552  Elaboration des différentes étapes du référenc...
# 553  Développement de la notoriété et l'image de ma...
# 554  Etude des besoins fonctionnels d'un ERP pour l...
# 555  Etude des besoins fonctionnels d'un réaprovisi...
#
#                                                 Skills  Number of Interns  \
# 0                                       C, BASH, YOCTO                  1
# 1                               PYTHON, C, BASH, YOCTO                  1
# 2                               WEB (PHP, HTML,...), C                  1
# 3                                    LINUX, C, C++, QT                  1
# 4                   C EMBARQUÉ, CHORA, STRUCTURED TEXT                  1
# ..                                                 ...                ...
# 551                            Marketing digital , ERP                  1
# 552      Marketing digital ,Référencement naturel ,SEO                  1
# 553  Marketing digital , Social media management , ...                  1
# 554  Scrum , Analyse fonctionnelle , gestion de pro...                  1
# 555  CBN , Kanban , gestion des approvisionnements ...                  1
#
#     Duration publication_date Location CompanyName
# 0      4 À 6       2023-01-05   ARIANA       ACTIA
# 1      4 À 6       2023-01-22   ARIANA       ACTIA
# 2      4 À 6       2022-12-21   ARIANA       ACTIA
# 3      4 À 6       2022-12-02   ARIANA       ACTIA
# 4      4 À 6       2023-01-14   ARIANA       ACTIA
# ..       ...              ...      ...         ...
# 551    4 à 6       2023-01-05     Sfax    Spark-it
# 552    4 à 6       2023-01-06     Sfax    Spark-it
# 553    4 à 6       2023-01-30     Sfax    Spark-it
# 554    4 à 6       2022-12-19     Sfax    Spark-it
# 555    4 à 6       2022-12-21     Sfax    Spark-it
#
# [556 rows x 8 columns]
